# %%
import sys
# !{sys.executable} -m pip install fastf1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 43.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import fastf1
import pandas as pd
import os

# %%
session = fastf1.get_session(2025,8,'Q')
session.name
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (24.0 KB) /root/.cache/fastf1
# WARNING:fastf1.fastf1.req:DEFAULT CACHE ENABLED! (24.0 KB) /root/.cache/fastf1
# 'Qualifying'

# %%
session.date
# Out:
# Timestamp('2025-05-24 14:00:00')

# %%
session.event
# Out:
# RoundNumber                                                      8
# Country                                                     Monaco
# Location                                                    Monaco
# OfficialEventName    FORMULA 1 TAG HEUER GRAND PRIX DE MONACO 2025
# EventDate                                      2025-05-25 00:00:00
# EventName                                        Monaco Grand Prix
# EventFormat                                           conventional
# Session1                                                Practice 1
# Session1Date                             2025-05-23 13:30:00+02:00
# Session1DateUtc                                2025-05-23 11:30:00
# Session2                                                Practice 2
# Session2Date                             2025-05-23 17:00:00+02:00
# Session2DateUtc                                2025-05-23 15:00:00
# Session3                                                Practice 3
# ...

# %%
scheduel = fastf1.get_event_schedule(2026)
print(scheduel)
# Out:
#     RoundNumber               Country           Location  \
# 0             0               Bahrain            Bahrain
# 1             0               Bahrain            Bahrain
# 2             1             Australia          Melbourne
# 3             2                 China           Shanghai
# 4             3                 Japan             Suzuka
# 5             4         United States      Miami Gardens
# 6             5                Canada           Montréal
# 7             6                Monaco        Monte Carlo
# 8             7                 Spain          Barcelona
# 9             8               Austria          Spielberg
# 10            9        United Kingdom        Silverstone
# 11           10               Belgium  Spa-Francorchamps
# 12           11               Hungary           Budapest
# 13           12           Netherlands          Zandvoort
# 14           13                 Italy              Monza
# ...

# %%
session.results
# Out:
# ---------------------------------------------------------------------------
# DataNotLoadedError                        Traceback (most recent call last)
# /tmp/ipykernel_1265/1284442285.py in <cell line: 0>()
# ----> 1 session.results
#
# /usr/local/lib/python3.12/dist-packages/fastf1/core.py in results(self)
#    1262         Data is available after calling `Session.load`
#    1263         """
# -> 1264         return self._get_property_warn_not_loaded('_results')
#    1265
#    1266     @property
#
# /usr/local/lib/python3.12/dist-packages/fastf1/core.py in _get_property_warn_not_loaded(self, name)
#    1229     def _get_property_warn_not_loaded(self, name):
#    1230         if not hasattr(self, name):
# -> 1231             raise exceptions.DataNotLoadedError(
#    1232                 "The data you are trying to access has not been loaded yet. "
#    1233                 "See `Session.load`"
#
# ...

# %%
session = fastf1.get_session(2025,8,'R')

# %%
session.results

# %%
session.load()
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.8.3]
# INFO:fastf1.fastf1.core:Loading data for Monaco Grand Prix - Race [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# INFO:fastf1.api:Fetching session info data...
# req            INFO 	Data has been written to cache!
# INFO:fastf1.fastf1.req:Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# INFO:fastf1.api:Fetching driver list...
# req            INFO 	Data has been written to cache!
# INFO:fastf1.fastf1.req:Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# ...

# %%
session.results
# Out:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 4             4      L NORRIS          NOR          norris          McLaren
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 6             6      I HADJAR          HAD          hadjar     Racing Bulls
# 31           31        E OCON          OCO            ocon     Haas F1 Team
# 30           30      L LAWSON          LAW          lawson     Racing Bulls
# 23           23       A ALBON          ALB           albon         Williams
# 55           55       C SAINZ          SAI           sainz         Williams
# 63           63     G RUSSELL          RUS         russell         Mercedes
# ...

# %%
lap_info = session.laps
print(lap_info)
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 0    0 days 00:57:36.090000    VER            1 0 days 00:01:27.020000
# 1    0 days 00:59:22.408000    VER            1 0 days 00:01:46.318000
# 2    0 days 01:01:11.223000    VER            1 0 days 00:01:48.815000
# 3    0 days 01:02:51.513000    VER            1 0 days 00:01:40.290000
# 4    0 days 01:04:12.313000    VER            1 0 days 00:01:20.800000
# ...                     ...    ...          ...                    ...
# 1420 0 days 02:32:33.863000    BEA           87 0 days 00:01:15.427000
# 1421 0 days 02:33:49.218000    BEA           87 0 days 00:01:15.355000
# 1422 0 days 02:35:04.583000    BEA           87 0 days 00:01:15.365000
# 1423 0 days 02:36:20.382000    BEA           87 0 days 00:01:15.799000
# 1424 0 days 02:37:37.606000    BEA           87 0 days 00:01:17.224000
#
#       LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# ...

# %%
df = lap_info[['DriverNumber','LapNumber','LapTime','Compound','TyreLife','Stint']]

# %%
print(df)
# Out:
#      DriverNumber  LapNumber                LapTime Compound  TyreLife  Stint
# 0               1        1.0 0 days 00:01:27.020000     HARD       1.0    1.0
# 1               1        2.0 0 days 00:01:46.318000     HARD       2.0    1.0
# 2               1        3.0 0 days 00:01:48.815000     HARD       3.0    1.0
# 3               1        4.0 0 days 00:01:40.290000     HARD       4.0    1.0
# 4               1        5.0 0 days 00:01:20.800000     HARD       5.0    1.0
# ...           ...        ...                    ...      ...       ...    ...
# 1420           87       72.0 0 days 00:01:15.427000   MEDIUM      55.0    3.0
# 1421           87       73.0 0 days 00:01:15.355000   MEDIUM      56.0    3.0
# 1422           87       74.0 0 days 00:01:15.365000   MEDIUM      57.0    3.0
# 1423           87       75.0 0 days 00:01:15.799000   MEDIUM      58.0    3.0
# 1424           87       76.0 0 days 00:01:17.224000   MEDIUM      59.0    3.0
#
# [1425 rows x 6 columns]
